# %% [markdown]
# <a href="https://colab.research.google.com/github/TasmeerJamali/Python-Practice-All/blob/main/concepts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Concepts of Google Collab#

# %%
# prompt: Write a Hello World program

print("Hello World")
# Out:
# Hello World

# %%
# prompt: write a program in which type my name : Tasmeer Jamali

name = "Tasmeer Jamali"
print(id(name))
# Out:
# 135461328121072

# %%
name:str = "Tasmeer Jamali"
print(name)

age:int = 20
print(age)

decimal:float = 3.14
print(decimal)
# Out:
# Tasmeer Jamali
# 20
# 3.14

# %%
# !nvidia-smi
# Out:
# Thu Sep 19 06:47:18 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install streamlit

# %%
#reff 01
name:str ="Tasmeer Jamali"
roll_no:str ="piaic123"
distance_learning:str="no"
city:str="karachi"
campus:str="karsaz"
center:str="bahria auditorium"
days_time:str="Sunday-2pm to 6pm"
batch:str="61"
print(name)
print(roll_no)
print(distance_learning)
print(city)
print(campus)
print(center)
print(days_time)
print(batch)
# Out:
# Tasmeer Jamali
# piaic123
# no
# karachi
# karsaz
# bahria auditorium
# Sunday-2pm to 6pm
# 61

# %%
#prompt: Read above cell # red 2 and fix the error to generate card and aslo remove font

#Install the Pillow library if not already installed
# !pip install Pillow

from PIL import Image, ImageDraw, ImageFont

#Create a blank card image
card_width = 600
card_height = 300
card_color = (255, 255, 255)  # White background
card = Image.new('RGB', (card_width, card_height), card_color)
draw = ImageDraw.Draw(card)

# Load the profile image (replace with your image path)
try:
  profile_img = Image.open('/content/Screenshot 2024-08-07 203814.png')
except FileNotFoundError:
  print("Error: Profile image not found. Please upload or provide the correct path.")
  # You might want to add code to handle this error, like uploading the image or exiting the program.

profile_img = profile_img.resize((100, 120))  # Resize profile image

# Create a green box for the image
box_width = 120
box_height = 140
box_x = 450
box_y = 30
draw.rectangle([(box_x, box_y), (box_x + box_width, box_y + box_height)], outline="green", width=2)

# Paste the profile image into the green box
card.paste(profile_img, (box_x + 10, box_y + 10))  # Add some padding

# Add text to the card
draw.text((20, 30), "Name: Tasmeer Jamali", fill="black")
draw.text((20, 60), "Roll No: PIAIC12345", fill="black")
draw.text((20, 90), "Distance learning: No", fill="black")
draw.text((20, 120), "City: Karachi", fill="black")
draw.text((20, 150), "Center: Bahria Auditorium", fill="black")
draw.text((20, 180), "Campus: Karsaz", fill="black")
draw.text((20, 210), "Days/Time: Sunday - 2 to 6", fill="black")
draw.text((20, 240), "Batch: 61", fill="black")

# Save the card image
card.save("/content/id_card_output.png")

# Display the card image
display(card)
# Out:
# ...
# <PIL.Image.Image image mode=RGB size=600x300>
